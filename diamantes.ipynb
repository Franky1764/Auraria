# %% [markdown]
# <a href="https://colab.research.google.com/github/Franky1764/Auraria/blob/main/diamantes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Diamonds.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %% [markdown]
# Fase 2: comprender los datos

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df.isnull().any().any()
# Out:
# np.False_

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0         carat    cut  color clarity         depth  \
# count   53940.000000  53940.000000  53940  53940   53940  53940.000000
# unique           NaN           NaN      5      7       8           NaN
# top              NaN           NaN  Ideal      G     SI1           NaN
# freq             NaN           NaN  21551  11292   13065           NaN
# mean    26970.500000      0.797940    NaN    NaN     NaN     61.749405
# std     15571.281097      0.474011    NaN    NaN     NaN      1.432621
# min         1.000000      0.200000    NaN    NaN     NaN     43.000000
# 25%     13485.750000      0.400000    NaN    NaN     NaN     61.000000
# 50%     26970.500000      0.700000    NaN    NaN     NaN     61.800000
# 75%     40455.250000      1.040000    NaN    NaN     NaN     62.500000
# max     53940.000000      5.010000    NaN    NaN     NaN     79.000000
#
#                table         price             x             y             z
# ...

# %%
df2=df.copy()

# %%
df2.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df2=df2.drop('Unnamed: 0',axis=1)

# %%
df2.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df2.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df2.cut.replace(['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],[1,2,3,4,5],inplace=True)
# Out:
# <ipython-input-23-8414f86a686d>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2.cut.replace(['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],[1,2,3,4,5],inplace=True)

# %%
df2.head()
# Out:
#    carat  cut color clarity  depth  table  price     x     y     z
# 0   0.23    5     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    4     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    2     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    4     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    2     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df2.color.unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
df2.color.replace(['J', 'I', 'H', 'G', 'F', 'E', 'D'],[10,9,8,7,6,5,4],inplace=True)
# Out:
# <ipython-input-26-40878dbcbddf>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2.color.replace(['J', 'I', 'H', 'G', 'F', 'E', 'D'],[10,9,8,7,6,5,4],inplace=True)
# <ipython-input-26-40878dbcbddf>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df2.head()
# Out:
#    carat  cut  color clarity  depth  table  price     x     y     z
# 0   0.23    5      5     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    4      5     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    2      5     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    4      9     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    2     10     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df2.clarity.unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
df2.clarity.replace(['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'],[1,2,3,4,5,6,7,8],inplace=True)
# Out:
# <ipython-input-29-877b639bc009>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2.clarity.replace(['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'],[1,2,3,4,5,6,7,8],inplace=True)

# %%
df2.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    5      5        2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    4      5        3   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    2      5        5   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    4      9        4   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    2     10        2   63.3   58.0    335  4.34  4.35  2.75

# %%
corr_matrix=df2.corr()

# %%
corr_matrix["price"].sort_values(ascending=False)
# Out:
# price      1.000000
# carat      0.921591
# x          0.884435
# y          0.865421
# z          0.861249
# color      0.172511
# table      0.127134
# depth     -0.010647
# cut       -0.053491
# clarity   -0.146800
# Name: price, dtype: float64

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df2.query("x==0 or y==0 or z==0")
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y    z
# 2207    1.00    4      7        2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    4      8        1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    4      7        2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    4      6        2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50    2      7        1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07    5      6        2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00    3      8        4   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15    5      7        4   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14    1      7        5   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    4      8        2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56    5      7        4   62.2   54.0  12800  0.00  0.00  0.0
# 26123   2.25    4      9        3   61.3   58.0  15397  8.52  8.42  0.0
# ...

# %%
sns.pairplot(df2)

# %%
sns.distplot(df2['price'])
# Out:
# <ipython-input-38-60e9d36e3612>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
len(df2.query("carat>3"))
# Out:
# 32

# %% [markdown]
# Fase 3: Removemos los outliers

# %%
df2.query("z>10 or y>10")
# Out:
#        carat  cut  color  clarity  depth  table  price      x      y      z
# 24067   2.00    4      8        2   58.9   57.0  12210   8.09  58.90   8.06
# 25998   4.01    4      9        1   61.0   61.0  15223  10.14  10.10   6.17
# 27415   5.01    1     10        1   65.5   59.0  18018  10.74  10.54   6.98
# 27630   4.50    1     10        1   65.8   58.0  18531  10.23  10.16   6.72
# 48410   0.51    3      5        5   61.8   54.7   1970   5.12   5.15  31.80
# 49189   0.51    5      5        5   61.8   55.0   2075   5.15  31.80   5.12

# %%
df2.query("z>10 or y>10").index
# Out:
# Index([24067, 25998, 27415, 27630, 48410, 49189], dtype='int64')

# %%
df2.drop(df2.query("z>10 or y>10").index,inplace=True)

# %%
df2.shape
# Out:
# (53934, 10)

# %%
df2.query("x==0 or y==0 or z==0")
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y    z
# 2207    1.00    4      7        2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    4      8        1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    4      7        2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    4      6        2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50    2      7        1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07    5      6        2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00    3      8        4   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15    5      7        4   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14    1      7        5   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    4      8        2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56    5      7        4   62.2   54.0  12800  0.00  0.00  0.0
# 26123   2.25    4      9        3   61.3   58.0  15397  8.52  8.42  0.0
# ...

# %%
df2.drop(df2.query("x==0 or y==0 or z==0").index,inplace=True)

# %%
df2.shape
# Out:
# (53914, 10)

# %%
sns.pairplot(df2)

# %%
df2.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    5      5        2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    4      5        3   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    2      5        5   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    4      9        4   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    2     10        2   63.3   58.0    335  4.34  4.35  2.75

# %%
df2["volume"]=df2["x"]*df2["y"]*df2["z"]

# %%
df2["volume"]
# Out:
# 0         38.202030
# 1         34.505856
# 2         38.076885
# 3         46.724580
# 4         51.917250
#             ...
# 53935    115.920000
# 53936    118.110175
# 53937    114.449728
# 53938    140.766120
# 53939    124.568444
# Name: volume, Length: 53914, dtype: float64

# %%
df2.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z  \
# 0   0.23    5      5        2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    4      5        3   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    2      5        5   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    4      9        4   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    2     10        2   63.3   58.0    335  4.34  4.35  2.75
#
#       volume
# 0  38.202030
# 1  34.505856
# 2  38.076885
# 3  46.724580
# 4  51.917250

# %%
df3 = df2.copy()

# %%
df3.drop(["x","y","z"],axis=1,inplace=True)

# %%
df3.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     volume
# 0   0.23    5      5        2   61.5   55.0    326  38.202030
# 1   0.21    4      5        3   59.8   61.0    326  34.505856
# 2   0.23    2      5        5   56.9   65.0    327  38.076885
# 3   0.29    4      9        4   62.4   58.0    334  46.724580
# 4   0.31    2     10        2   63.3   58.0    335  51.917250
